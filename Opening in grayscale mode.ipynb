# %%
# Python program to explain cv2.imread() method 

import cv2 
# Using cv2.imread() method 
# Using 0 to read image in grayscale mode 
img = cv2.imread(r'flower.png', cv2.IMREAD_GRAYSCALE) 

cv2.imshow('image', img) 
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ![Screenshot%202023-11-21%20231108.png](attachment:Screenshot%202023-11-21%20231108.png)
