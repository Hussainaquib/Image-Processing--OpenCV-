# %% [markdown]
# ## Original Photo

# %% [markdown]
# ![Boy.png](attachment:Boy.png)

# %%
import cv2
img=cv2.imread("Boy.png")
print(img.shape)

img_resize=cv2.resize(img,(256,256))
print(img_resize.shape)

cv2.imshow("window",img_resize)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# (389, 350, 3)
# (256, 256, 3)

# %% [markdown]
# ![Screenshot%202023-11-21%20225956.png](attachment:Screenshot%202023-11-21%20225956.png)

# %% [markdown]
# ## Half the size of original photo

# %%
import cv2
img=cv2.imread("Boy.png")
print(img.shape)

img_resize=cv2.resize(img,(img.shape[1]//2,img.shape[0]//2))
print(img_resize.shape)

cv2.imshow("window",img_resize)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# (389, 350, 3)
# (194, 175, 3)

# %% [markdown]
# ![Screenshot%202023-11-21%20230816.png](attachment:Screenshot%202023-11-21%20230816.png)
