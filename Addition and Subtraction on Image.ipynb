# %% [markdown]
# ## Addition

# %%
import cv2
import numpy as np

image1 = cv2.imread('Planet.jpg')  
image2 = cv2.imread('Stars.jpg')
# cv2.addWeighted is applied over the 
# image inputs with applied parameters 
weightedSum = cv2.addWeighted(image1, 0.5, image2, 0.4, 0) 


cv2.imshow("window",weightedSum)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ![Screenshot%202023-11-25%20005857.png](attachment:Screenshot%202023-11-25%20005857.png)

# %% [markdown]
# ## Subtraction

# %%
import cv2
import numpy as np

image1 = cv2.imread('Boy.png')  
image2 = cv2.imread('boy3.png')

sub = cv2.subtract(image1, image2) 


cv2.imshow("window",weightedSum)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ![Screenshot%202023-11-25%20011001.png](attachment:Screenshot%202023-11-25%20011001.png)
